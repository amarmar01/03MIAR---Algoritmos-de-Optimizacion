# %% [markdown]
# <a href="https://colab.research.google.com/github/amarmar01/03MIAR---Algoritmos-de-Optimizacion/blob/main/TRABAJO_FINAL/Trabajo_Pr%C3%A1ctico_Algoritmos%20(Adri%C3%A1n_Mart%C3%ADnez).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Algoritmos de optimización - Trabajo Práctico<br>
# **Nombre y Apellidos**: Adrián Martínez Martín<br>
# **Url**: https://github.com/.../03MAIR---Algoritmos-de-Optimizacion---/tree/master/TrabajoPractico<br>
# **Google Colab**: https://colab.research.google.com/drive/1jdSaQhkrICUpR2MJ-xII-kkCshkEFSNa <br>
#
# Problema:
# >**Organizar los horarios de partidos de una jornada de La Liga**<br>
#
# Descripción del problema:
#
# Desde la La Liga de fútbol profesional se pretende organizar los horarios de los partidos de liga de cada jornada. Se conocen algunos datos que nos deben llevar a diseñar un algoritmo que realice la asignación de los partidos a los horarios de forma que maximice la audiencia.
#
# Los horarios disponibles se conocen a priori y son los siguientes:
#
# ![Captura de pantalla 2025-03-05 205342.png](data:image/png;base64,...)
#
# Tenemos los equipos clasificados en 3 categorías: A,B y C, según el número de seguidores. Hay 3 equipos en categoría A, 11 en categoría B y 6 equipos en categoría C. Se conoce estadísticamente la audiencia que genera cada partido según los equipos que se enfrentan y en horario de sábado a las 20h (el mejor en todos los casos)
#
# ![image.png](data:image/png;base64,...)
#
# SD
# ....

# %% [markdown]
# #Modelo
# - ¿Como represento el espacio de soluciones?
# - ¿Cual es la función objetivo?
# - ¿Como implemento las restricciones?

# %%
#Respuesta

# %% [markdown]
# #Análisis
# - ¿Que complejidad tiene el problema?. Orden de complejidad y Contabilizar el espacio de soluciones

# %%
#Respuesta

# %% [markdown]
# #Diseño
# - ¿Que técnica utilizo? ¿Por qué?

# %%
#Respuesta
